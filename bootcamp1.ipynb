# %% [markdown]
# <a href="https://colab.research.google.com/github/Level-up-every-second/BootCamp-1/blob/main/bootcamp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data tpes -4

# %%
inte = 20
stri = "hel"
floa = 20.13
boole = False

# %%
l = ["1","2","3","4","5"]
print(l[0],l[4])

# %%
l=[1,2,3,4]
for i in l:
  if(i>40):
    print("Pass")
  else:
    print("Fail")
# Out:
# Fail
# Fail
# Fail
# Fail

# %%
l=[0,-1,5,100]
for i in l:
  if(i==0):
    print("zero")
  elif(i>0):
    print("+ve")
  else:
    print("-ve")

# %%
d = {
    "a":[5,71,60],
    "b":[6,66,76],
    "c":[1,81,97],
    "d":[8,99,87],
    "e":[7,90,92]
}
name = input()
if(d[name][2]>75):
  print("strong perfomance")
elif(d[name][2]>=40):
  print("need improvement")
else:
  print("repeat class")

if(d[name][1]<75):
  print("warning-low attendance")

if(d[name][0]<2):
  print("warning-study more")
# Out:
# c
# strong perfomance
# warning-study more

# %%
# Student Starter Code
transactions = [
    {"transaction_id": "TX101", "amount": 6200, "method": "Credit Card"},
    {"transaction_id": "TX102", "amount": 5500, "method": "Gift Card"},
    {"transaction_id": "TX103", "amount": 1200, "method": "Gift Card"},
    {"transaction_id": "TX104", "amount": 8000, "method": "Gift Card"},
    {"transaction_id": "TX105", "amount": 450, "method": "PayPal"}
]

flagged_transactions = []

# Write your code below to find anomalous patterns|


for i in range(len(transactions)):
  if(transactions[i]["amount"]>5000 and transactions[i]["method"]=="Gift Card"):
    flagged_transactions.append(transactions[i]["transaction_id"])

for i in flagged_transactions:
  print(i)
# Out:
# TX102
# TX104

# %%
#Student Starter Code
transactions = [
    {"transaction_id": "TX101", "amount": 6200, "method": "Credit Card"},
    {"transaction_id": "TX102", "amount": 5500, "method": "Gift Card"},
    {"transaction_id": "TX103", "amount": 1200, "method": "Gift Card"},
    {"transaction_id": "TX104", "amount": 8000, "method": "Gift Card"},
    {"transaction_id": "TX105", "amount": 450, "method": "PayPal"}
]

flagged_transactions = []

# Write your code below to find anomalous patterns|


for i in transactions:
  if(i["amount"]>5000 and i["method"]=="Gift Card"):
    flagged_transactions.append(i["transaction_id"])

for i in flagged_transactions:
  print(i)
# Out:
# TX102
# TX104
